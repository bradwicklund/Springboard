# %%
import sqlite3
from sqlite3 import Error

 
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by the db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
 
    return conn

 
def select_all_tasks(conn):
    """
    Query all rows in the tasks table
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    
    query1 = """
        SELECT
    f.facid,
    f.name,
    SUM(
        CASE 
            WHEN m.memid = 0 THEN f.guestcost * b.slots
            ELSE f.membercost * b.slots
        END
    ) AS total_revenue
FROM Bookings AS b
INNER JOIN Facilities AS f
    ON b.facid = f.facid
INNER JOIN Members AS m
    ON b.memid = m.memid
WHERE total_revenue < 1000
GROUP BY f.facid, f.name
ORDER BY total_revenue;
        
        """
    cur.execute(query1)
 
    rows = cur.fetchall()
 
    for row in rows:
        print(row)


def main():
    database = "sqlite_db_pythonsqlite.db"
 
    # create a database connection
    conn = create_connection(database)
    with conn: 
        print("2. Query all tasks")
        select_all_tasks(conn)
 
 
if __name__ == '__main__':
    main()
# Out:
# 2.6.0
# 2. Query all tasks
# /var/folders/fx/hgr0qjbs13q4rlhs7k4n4ktm0000gn/T/ipykernel_26756/896599870.py:14: DeprecationWarning: version is deprecated and will be removed in Python 3.14
#   print(sqlite3.version)
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[12], line 68
#      64         select_all_tasks(conn)
#      67 if __name__ == '__main__':
# ---> 68     main()
#
# Cell In[12], line 64, in main()
#      62 with conn:
#      63     print("2. Query all tasks")
# ---> 64     select_all_tasks(conn)
#
# Cell In[12], line 49, in select_all_tasks(conn)
#      27 cur = conn.cursor()
#      29 query1 = """
#      30     SELECT
#      31 f.facid,
#    (...)
#      47
#      48     """
# ---> 49 cur.execute(query1)
#      51 rows = cur.fetchall()
#      53 for row in rows:
#
# OperationalError: misuse of aggregate: SUM()
